# %%
result <- radiant.design::sample_size_comp(
  type = "proportion",
  p1 = 0.51,
  p2 = 0.52,
  conf_lev = 0.95,
  power = 0.8
)
summary(result)
# Out:
# Sample size calculation for comparison of proportions
# Sample size 1    : 39,208
# Sample size 2    : 39,208
# Total sample size: 78,416
# Proportion 1     : 0.51
# Proportion 2     : 0.52
# Effect size      : 0.02000934
# Confidence level : 0.95
# Power            : 0.8
# Alternative      : two.sided

# %%
dframe <- data.frame(
    col1 = c("x", "y", "z"),
    col2 = c(3, 4, 5)
)

# %%
library(ggplot2)
p <- ggplot(dframe, aes(x=col1, y=col2)) + geom_bar(stat="identity")
print(p)
# Out:
# plot without title

# %%
# start radiant from a notebook in the notebook directory
# will not work on the MSBA server
# radiant::radiant(host="0.0.0.0", port=8181)
